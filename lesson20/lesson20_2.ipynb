# %%
import numpy as np
import pandas as pd

df = pd.DataFrame({'key1':['a', 'a', 'b', 'b', 'a'],
                  'key2':['one', 'two', 'one', 'two', 'one'],
                  'data1': np.random.randn(5),
                  'data2':np.random.randn(5)})
df
# Out:
#   key1 key2     data1     data2
# 0    a  one -1.451815  1.110478
# 1    a  two -0.811380 -0.213752
# 2    b  one -0.872998 -1.163974
# 3    b  two -1.271223 -0.234913
# 4    a  one  2.242097 -0.642109

# %% [markdown]
# ### groupby物件後面一定接統計

# %%
df.groupby(by="key1")[['data1','data2']].sum()
# Out:
#          data1     data2
# key1
# a    -0.021098  0.254617
# b    -2.144221 -1.398887

# %%
df1 = df.groupby(by=['key1','key2']).sum()
df1.columns.name = "data"
df1
# Out:
# data          data1     data2
# key1 key2
# a    one   0.790282  0.468369
#      two  -0.811380 -0.213752
# b    one  -0.872998 -1.163974
#      two  -1.271223 -0.234913

# %%
df1.stack().unstack(level=['key2','data'])
# Out:
# key2       one                 two
# data     data1     data2     data1     data2
# key1
# a     0.790282  0.468369 -0.811380 -0.213752
# b    -0.872998 -1.163974 -1.271223 -0.234913

# %%
df1 = df.groupby(by=['key1','key2']).agg([("加總","sum"),("平均","mean")])
df1
# Out:
#               data1               data2
#                  加總        平均        加總        平均
# key1 key2
# a    one   0.790282  0.395141  0.468369  0.234185
#      two  -0.811380 -0.811380 -0.213752 -0.213752
# b    one  -0.872998 -0.872998 -1.163974 -1.163974
#      two  -1.271223 -1.271223 -0.234913 -0.234913
