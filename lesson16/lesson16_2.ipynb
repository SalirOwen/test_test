# %% [markdown]
# scores = pd.DataFrame(np.random.randint(50, 101, size=(50, 5)), columns=list('ABCDE'))

# %%
import numpy as np
import pandas as pd
#建立50位學生5個分數,每個分數的值是50~100之間的隨機整數
scores = np.random.randint(50,101,size=(50, 5))
score_pd = pd.DataFrame(scores,
             columns=['國文', '英文', '數學', '地理', '歷史'],
             index=[f'學生{index}' for index in range(1,51)])
type(score_pd.index)
score_pd.columns.name = '科目'
score_pd.index.name = '學號'
sum_series = np.sum(score_pd, axis=1)
mean_series = score_pd.mean(axis=1)
score_pd['總分'] = sum_series
score_pd['平均'] = mean_series

# %%
score_pd
# Out:
# 科目    國文  英文   數學   地理  歷史   總分    平均
# 學號
# 學生1   77  76   71   87  97  408  81.6
# 學生2   59  58  100   70  83  370  74.0
# 學生3   93  74   66   93  85  411  82.2
# 學生4   95  95   89   69  59  407  81.4
# 學生5   54  68   85   69  70  346  69.2
# 學生6   94  82   68   57  94  395  79.0
# 學生7   61  97   83   90  98  429  85.8
# 學生8   67  79   91   87  88  412  82.4
# 學生9   95  92   82   96  56  421  84.2
# 學生10  57  85   91   56  63  352  70.4
# 學生11  86  56   96   56  82  376  75.2
# 學生12  65  87   68   84  91  395  79.0
# 學生13  60  87   57   76  85  365  73.0
# 學生14  94  92   70   64  59  379  75.8
# 學生15  77  97   53   75  91  393  78.6
# 學生16  97  84   60   92  65  398  79.6
# 學生17  63  78   94   70  65  370  74.0
# 學生18  96  52   72   66  67  353  70.6
# 學生19  93  92   91   70  73  419  83.8
# 學生20  55  69   79   59  55  317  63.4
# 學生21  99  65   60   88  59  371  74.2
# 學生22  96  86   78   54  70  384  76.8
# 學生23  80  95   60   65  75  375  75.0
# 學生24  72  55   91   66  92  376  75.2
# 學生25  65  62   58   80  99  364  72.8
# 學生26  66  89   84   63  53  355  71.0
# 學生27  86  75   68   50  57  336  67.2
# 學生28  53  60   55   86  77  331  66.2
# 學生29  61  76   90   82  86  395  79.0
# 學生30  53  54   50   98  58  313  62.6
# 學生31  63  81   84   64  67  359  71.8
# 學生32  89  82   63   84  67  385  77.0
# 學生33  65  76   90   84  75  390  78.0
# 學生34  63  56   52   93  76  340  68.0
# 學生35  89  88   56   74  96  403  80.6
# 學生36  78  94   73   92  78  415  83.0
# 學生37  57  71   83   76  58  345  69.0
# 學生38  70  99   72   95  95  431  86.2
# 學生39  69  59   97   99  57  381  76.2
# 學生40  60  89   65   71  62  347  69.4
# 學生41  60  84   66   55  80  345  69.0
# 學生42  95  56   68  100  88  407  81.4
# 學生43  91  72   62   50  69  344  68.8
# 學生44  79  92   72   55  70  368  73.6
# 學生45  65  90   65   50  59  329  65.8
# 學生46  58  77   67   53  79  334  66.8
# 學生47  92  56   95   55  79  377  75.4
# 學生48  84  59   80   53  99  375  75.0
# 學生49  96  84   77   68  70  395  79.0
# 學生50  88  67   65   72  84  376  75.2
